# %%
from sklearn.datasets import load_digits
from sklearn import linear_model
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
digits=load_digits()

# %%
plt.gray()

# %%
for i in range(20,27):
    plt.matshow(digits.images[i])

# %%
dir(digits)
# Out:
# ['DESCR', 'data', 'feature_names', 'frame', 'images', 'target', 'target_names']

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(digits.data,digits.target,test_size=0.1)

# %%
reg=linear_model.LogisticRegression()
reg.fit(x_train,y_train)
# Out:
# c:\users\thedg\appdata\local\programs\python\python38\lib\site-packages\sklearn\linear_model\_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression()

# %%
reg.predict(x_test)
# Out:
# array([6, 0, 9, 6, 4, 6, 4, 3, 6, 2, 9, 0, 1, 4, 2, 7, 4, 1, 9, 5, 4, 8,
#        4, 1, 9, 4, 4, 7, 5, 1, 1, 9, 0, 1, 4, 4, 2, 5, 8, 6, 4, 1, 1, 3,
#        4, 3, 6, 6, 9, 1, 3, 7, 2, 6, 0, 6, 9, 4, 2, 1, 8, 2, 5, 1, 3, 5,
#        8, 4, 6, 9, 4, 6, 6, 7, 8, 9, 6, 0, 5, 0, 5, 0, 9, 8, 1, 8, 3, 6,
#        0, 2, 9, 6, 8, 8, 3, 8, 7, 1, 2, 5, 2, 1, 4, 7, 4, 5, 1, 4, 4, 8,
#        9, 7, 2, 8, 6, 7, 0, 6, 9, 8, 6, 1, 1, 5, 1, 7, 2, 3, 4, 6, 2, 2,
#        2, 2, 8, 7, 5, 6, 3, 0, 4, 2, 3, 0, 8, 8, 9, 4, 6, 0, 7, 7, 1, 6,
#        8, 7, 0, 5, 3, 0, 1, 9, 0, 5, 7, 7, 3, 0, 4, 3, 7, 0, 8, 2, 2, 1,
#        0, 5, 9, 4])

# %%
reg.score(x_test,y_test)
# Out:
# 0.9722222222222222

# %%
reg.predict_proba(digits.data[20:27])
# Out:
# array([[1.00000000e+00, 6.69218668e-12, 6.23406661e-14, 1.01425512e-18,
#         2.25898845e-13, 1.57120744e-11, 9.08537968e-11, 8.82715477e-11,
#         1.31229618e-12, 1.29121146e-13],
#        [2.66494196e-17, 9.99998872e-01, 4.47675469e-14, 2.07589771e-08,
#         6.07597964e-07, 1.96644987e-13, 1.94948613e-11, 1.93356235e-11,
#         4.96972462e-07, 2.13287428e-09],
#        [1.21496043e-18, 4.51111721e-11, 1.00000000e+00, 8.74815839e-12,
#         3.32847550e-20, 1.38886902e-16, 3.23856950e-15, 7.72807626e-14,
#         1.18911923e-14, 5.42694875e-18],
#        [2.34255533e-13, 3.06622195e-17, 3.66536401e-08, 9.99999880e-01,
#         1.83911811e-22, 8.02466000e-08, 2.77460057e-21, 1.95545407e-09,
#         3.22292521e-13, 8.49981642e-10],
#        [2.74469216e-10, 1.83459037e-03, 2.48487745e-18, 4.28513588e-17,
#         9.98131301e-01, 1.32155897e-14, 3.25920594e-05, 4.51344394e-08,
#         1.47131507e-06, 1.06484356e-14],
#        [9.94170597e-08, 1.05196593e-13, 3.05642662e-13, 3.33123483e-07,
#         1.18826309e-11, 9.99999331e-01, 4.28371254e-11, 7.07413855e-10,
#         2.35972130e-07, 2.71181100e-11],
#        [2.92544021e-07, 3.50250718e-09, 8.37250676e-11, 1.28507139e-13,
#         7.37039753e-11, 1.49770700e-13, 9.99916809e-01, 5.41834484e-20,
#         8.28949574e-05, 3.40053056e-23]])

# %%
digits.data[20]
# Out:
# array([ 0.,  0.,  3., 13., 11.,  7.,  0.,  0.,  0.,  0., 11., 16., 16.,
#        16.,  2.,  0.,  0.,  4., 16.,  9.,  1., 14.,  2.,  0.,  0.,  4.,
#        16.,  0.,  0., 16.,  2.,  0.,  0.,  0., 16.,  1.,  0., 12.,  8.,
#         0.,  0.,  0., 15.,  9.,  0., 13.,  6.,  0.,  0.,  0.,  9., 14.,
#         9., 14.,  1.,  0.,  0.,  0.,  2., 12., 13.,  4.,  0.,  0.])

# %%
plt.matshow(digits.images[20])
